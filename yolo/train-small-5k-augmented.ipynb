# %% [markdown]
# <a href="https://colab.research.google.com/github/DamnScallion/Visionary-Unicorns-Project/blob/main/yolo/train-small-5k-augmented.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clone files from our GitHub Repo

# %%
# !git clone https://github.com/DamnScallion/Visionary-Unicorns-Project.git
# Out:
# Cloning into 'Visionary-Unicorns-Project'...
# remote: Enumerating objects: 26233, done.
# remote: Counting objects: 100% (15292/15292), done.
# remote: Compressing objects: 100% (10169/10169), done.
# remote: Total 26233 (delta 134), reused 15269 (delta 118), pack-reused 10941
# Receiving objects: 100% (26233/26233), 179.58 MiB | 18.47 MiB/s, done.
# Resolving deltas: 100% (180/180), done.
# Updating files: 100% (27453/27453), done.

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 605.1/605.1 kB 10.2 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
from ultralytics import YOLO
import os

# %%
ROOT_DIR = '/content/Visionary-Unicorns-Project/yolo/config'

# %% [markdown]
# # Trainning YOLO with our dataset

# %%
# Create a new YOLO model from scratch
# Below is YOLOv8 Small size model architecture
model = YOLO('yolov8s.pt')
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:02<00:00, 9.87MB/s]

# %%
# Train the small size yolo model with 5k augmented dataset for 100 epochs
results = model.train(data=os.path.join(ROOT_DIR, 'yolo_config_5k_augmented.yaml'), epochs=100, imgsz=224, name='yolov8s_default_5k_augmented')
# Out:
# Ultralytics YOLOv8.0.144 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # Save the model to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
# !scp -r /content/runs/detect/yolov8s_default_5k_augmented '/content/drive/MyDrive/COMP9517/YOLO_Loss result'
