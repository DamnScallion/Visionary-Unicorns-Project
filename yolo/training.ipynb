# %% [markdown]
# <a href="https://colab.research.google.com/github/DamnScallion/Visionary-Unicorns-Project/blob/main/yolo/training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Please run this file in Google Colab

# %% [markdown]
# ### Clone files from our GitHub Repo
# ### https://github.com/DamnScallion/Visionary-Unicorns-Project

# %%
# !git clone https://github.com/DamnScallion/Visionary-Unicorns-Project.git
# Out:
# Cloning into 'Visionary-Unicorns-Project'...
# remote: Enumerating objects: 26245, done.
# remote: Counting objects: 100% (15304/15304), done.
# remote: Compressing objects: 100% (10181/10181), done.
# remote: Total 26245 (delta 142), reused 15269 (delta 118), pack-reused 10941
# Receiving objects: 100% (26245/26245), 179.63 MiB | 30.08 MiB/s, done.
# Resolving deltas: 100% (188/188), done.
# Updating files: 100% (27455/27455), done.

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 605.6/605.6 kB 8.7 MB/s eta 0:00:00
# ...

# %%
import os
from ultralytics import YOLO

# %%
ROOT_DIR = '/content/Visionary-Unicorns-Project/yolo/config'

# %% [markdown]
# # Training Models with our dataset

# %% [markdown]
# ## To get the best model, we need to conduct several training experiments and evaluate each.
#
# ### Train on 4 different models:
# *   yolov8n (Nano-Model)
# *   yolov8s (Small-Model)
# *   yolov8m (Medium-Model)
# *   customYolov8n (Custom-Model)
#
# ### Train with 2 different size dataset:
# *   Original (500 Images)
# *   5k-Augmented (5500 Images)
#
# ### Test with 1 validation dataset:
# *   Valid (72 Images)
#
# ### Hyperparameter Choices to Train:
# *   Train each model for 50 epochs. We will try to get the best possible results with limited training. As we have 5500 images in 5k-Augmented, even 50 epochs will take quite some time to train and should give decent results.
# *   Train each model with batch size 16. So it will be a fair comparison between the models.
# *   Train each model with image size 224. The given original image size is 640. But as we do image denoise and augmention before training, set to small size is base on trade-off model performance and training time.
#
# ### (PS: Train and Valid paths setting on yolo_config.yaml and yolo_config_5k_augmented.yaml)

# %% [markdown]
# ## Train on Nano-Model with Original data

# %%
model_yolov8n_orig = YOLO('yolov8n.pt')
results_yolov8n_orig = model_yolov8n_orig.train(data=os.path.join(ROOT_DIR, 'yolo_config.yaml'), epochs=50, batch=16, imgsz=224, name='yolov8n_orig')
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 16.4MB/s]
# Ultralytics YOLOv8.0.145 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ## Train on Nano-Model with 5k-Augmented data

# %%
model_yolov8n_5k_aug = YOLO('yolov8n.pt')
results_yolov8n_5k_aug = model_yolov8n_5k_aug.train(data=os.path.join(ROOT_DIR, 'yolo_config_5k_augmented.yaml'), epochs=50, batch=16, imgsz=224, name='yolov8n_5k_aug')
# Out:
# Ultralytics YOLOv8.0.145 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ## Train on Small-Model with Original data

# %%
model_yolov8s_orig = YOLO('yolov8s.pt')
results_yolov8s_orig = model_yolov8s_orig.train(data=os.path.join(ROOT_DIR, 'yolo_config.yaml'), epochs=50, batch=16, imgsz=224, name='yolov8s_orig')
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 167MB/s]
# Ultralytics YOLOv8.0.145 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ## Train on Small-Model with 5k-Augmented data

# %%
model_yolov8s_5k_aug = YOLO('yolov8s.pt')
results_yolov8s_5k_aug = model_yolov8s_5k_aug.train(data=os.path.join(ROOT_DIR, 'yolo_config_5k_augmented.yaml'), epochs=50, batch=16, imgsz=224, name='yolov8s_5k_aug')
# Out:
# Ultralytics YOLOv8.0.145 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ## Train on Medium-Model with Original data

# %%
model_yolov8m_orig = YOLO('yolov8m.pt')
results_yolov8m_orig = model_yolov8m_orig.train(data=os.path.join(ROOT_DIR, 'yolo_config.yaml'), epochs=50, batch=16, imgsz=224, name='yolov8m_orig')
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 219MB/s]
# Ultralytics YOLOv8.0.145 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ## Train on Medium-Model with 5k-Augmented data

# %%
model_yolov8m_5k_aug = YOLO('yolov8m.pt')
results_yolov8m_5k_aug = model_yolov8m_5k_aug.train(data=os.path.join(ROOT_DIR, 'yolo_config_5k_augmented.yaml'), epochs=50, batch=16, imgsz=224, name='yolov8m_5k_aug')
# Out:
# Ultralytics YOLOv8.0.145 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # Define Custom Model

# %%
import torch
import torch.nn as nn


class DiceLoss(nn.Module):
    def __init__(self):
        super(DiceLoss, self).__init__()

    def forward(self, pred, target):
        smooth = 1e-5
        intersection = (pred * target).sum()
        dice_coefficient = (2.0 * intersection + smooth) / (pred.sum() + target.sum() + smooth)
        dice_loss = 1.0 - dice_coefficient
        return dice_loss


class CustomBinaryDiceLoss(nn.Module):
    def __init__(self):
        super(CustomBinaryDiceLoss, self).__init__()
        self.dice_loss = DiceLoss()

    def forward(self, pred, target):
        # Assuming `pred` is the predicted output and `target` is the target tensor with binary labels
        loss = self.dice_loss(pred, target)
        return loss


class CustomYOLOv8n(YOLO):
    def __init__(self, config_path):
        super(CustomYOLOv8n, self).__init__(config_path)
        self.loss_fn = CustomBinaryDiceLoss()

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ## Train on Custom-Model with Original data

# %%
model_custom_orig = CustomYOLOv8n('yolov8n.yaml') # build a new model from YAML
results_custom_orig = model_custom_orig.train(data=os.path.join(ROOT_DIR, 'yolo_config.yaml'), epochs=50, batch=16, imgsz=224, name='custom_orig')
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %% [markdown]
# ## Train on Custom-Model with 5k-Augmented data

# %%
model_custom_5k_aug = CustomYOLOv8n('yolov8n.yaml') # build a new model from YAML
results_custom_5k_aug = model_custom_5k_aug.train(data=os.path.join(ROOT_DIR, 'yolo_config_5k_augmented.yaml'), epochs=50, batch=16, imgsz=224, name='custom_5k_aug')
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %% [markdown]
# # Save the model to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
# !scp -r /content/runs/detect/ '/content/drive/My Drive/COMP9517/YOLO_Train_Results'
